# %% [markdown]
# <a href="https://colab.research.google.com/github/Xavier7723-uabc/Python/blob/main/practica1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **1.- Programa en Python Mostrar un mensaje que diga “HOLA MUNDO” en un solo renglón usando 2 print**

# %%
print("Hola mundo", end="--")
print("Hola mundo")
# Out:
# Hola mundo--Hola mundo

# %%
print("Hola","mundo")
# Out:
# Hola mundo

# %%
edad = 21
nombre ="Xavier"
print("Hola ",nombre,"tienes ",edad,"años")
# Out:
# Hola  Xavier tienes  21 años

# %%
edad = int(input("Dame tu edad"))
print(f"Hola {nombre} tu tienes {edad} años de edad")
print (f"Carlos el proximo año tendras {edad+1} años")
# Out:
# Dame tu edad21
# Hola Xavier tu tienes 21 años de edad
# Carlos el proximo año tendras 22 años
