# %% [markdown]
# <a href="https://colab.research.google.com/github/Xavier7723-uabc/Python/blob/main/Actividad_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **1.- Programa en Python Mostrar un mensaje que diga “HOLA MUNDO” en un solo renglón usando 2 print**

# %%
print("HOLA", end=" ")
print("MUNDO")
# Out:
# HOLA MUNDO

# %% [markdown]
# # **2.- Programa en Python que lea 2 números, realizar la suma y desplegar la suma de los 2 números**

# %%
n1=int(input("Escribe un numero: "))
n2=int(input("Escribe otro numero: "))
suma=n1+n2
print("La suma de los numeros es=",suma)
# Out:
# Escribe un numero: 2
# Escribe otro numero: 2
# La suma de los numeros es=  4

# %% [markdown]
# # **3.- Programa en Python que lea 2 números y realice las 4 operaciones básicas**

# %%
n1=int(input("Dame un numero:"))
n2=int(input("Dame otro numero"))
s=n1+n2
r=n1-n2
m=n1*n2
d=n1/n2
print("La suma de los numeros es=",s)
print("La resta de los numeros es=",r)
print("La multiplicacion de los numeros es=",m)
print("La division de los numeros es=",d)
# Out:
# Dame un numero:6
# Dame otro numero3
# La suma de los numeros es= 9
# La resta de los numeros es= 3
# La multiplicacion de los numeros es= 18
# La division de los numeros es= 2.0

# %% [markdown]
# # **4.- Programa en Python Que sirva para calcular el área de un triángulo**

# %%
base=int(input("Escribe la base="))
alt=int(input("Escribe la altura="))
area=(base*alt)/2
print(f"El area del triangulo es={area}")
# Out:
# Escribe la base=3
# Escribe la altura=4
# El area del triangulo es=6.0

# %% [markdown]
# # **5.- Programa en Python que lea una medida en centímetros y desplegar la misma medida pero convertida en pies y pulgadas**

# %%
cm=int(input("Dame una medida en centimetros:"))
pies=cm*0.0328084
pulgadas=cm*0.393701
print("La medida convertida a pies es igual a=",pies)
print("La medida convertida a pulgadas es igual a=",pulgadas)
# Out:
# Dame una medida en centimetros:20
# La medida convertida a pies es igual a= 0.6561680000000001
# La medida convertida a pulgadas es igual a= 7.874020000000001

# %% [markdown]
# # **6.- Programa en Python que lea una temperatura en grados centígrados y desplegarla en Grados Fahrenheit y grados kelvin**

# %%
gc=int(input("Escribe una termperatura en grados centigradfos"))
gf=(1.8*gc)+32
gk=gc+273.15
print("La temperatura convertida a grados Farenheit es=",gf)
print("La temperatura convertida a grados Kelving=",gk)
# Out:
# Escribe una termperatura en grados centigradfos20
# La temperatura convertida a grados Farenheit es= 68.0
# La temperatura convertida a grados Kelving= 293.15

# %% [markdown]
# # **7. Promedio de Calificaciones**
#
# ● Objetivo: Calcular el promedio de 4 calificaciones
#
# ● Conceptos: Operaciones con lista de valores, promedios

# %%
c1=int(input("Ecribe una calificacion:"))
c2=int(input("Ecribe una calificacion:"))
c3=int(input("Ecribe una calificacion:"))
c4=int(input("Ecribe una calificacion:"))
prom=(c1+c2+c3+c4)/4
print("El promedio es=",prom)
# Out:
# Ecribe una calificacion:50
# Ecribe una calificacion:60
# Ecribe una calificacion:70
# Ecribe una calificacion:70
# El promedio es= 62.5
